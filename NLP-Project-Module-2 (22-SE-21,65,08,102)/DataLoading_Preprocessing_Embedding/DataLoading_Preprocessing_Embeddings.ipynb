# %% [markdown]
# # Data Loading

# %%
import pandas as pd

df_train = pd.read_json('/content/train.json', lines=True)

# %%
import pandas as pd

df_test = pd.read_json('/content/test.json', lines=True)

# %%
import pandas as pd

df_validation = pd.read_json('/content/val.json', lines=True)

# %%
df_train.to_csv('train_df.csv')

# %%
df_test.to_csv('test_df.csv')

# %%
df_validation.to_csv('valid_df.csv')

# %%
df_train.head()
# Out:
#        id                                              title  \
# 0  hhcq6e                          Found out something awful
# 1  d0bobn                I just want to feel wanted ya know?
# 2  wy400i                                               Done
# 3  crkjga  When nobody else celebrates you, learn to cele...
# 4  zq1lwl                                           goodbye.
#
#                                                 post  \
# 0  My mum had a boyfriend when I was around 6 or ...
# 1  Like, I have a ton of friends, I talk to them ...
# 2  I’m writing this as I sit on the side of the r...
# 3  Feeling unloved can have a huge impact on the ...
# 4  I'm done. I have a bottle of jack danials and ...
#
#                                                 text  upvotes  \
# 0  Found out something awful ### My mum had a boy...       53
# 1  I just want to feel wanted ya know? ### Like, ...       51
# 2  Done ### I’m writing this as I sit on the side...        8
# ...

# %%
train=df_train[['post','emotions']]

# %%
train.head()
# Out:
#                                                 post  \
# 0  My mum had a boyfriend when I was around 6 or ...
# 1  Like, I have a ton of friends, I talk to them ...
# 2  I’m writing this as I sit on the side of the r...
# 3  Feeling unloved can have a huge impact on the ...
# 4  I'm done. I have a bottle of jack danials and ...
#
#                                             emotions
# 0                     [anger, hopelessness, sadness]
# 1  [loneliness, sadness, emptiness, hopelessness,...
# 2  [loneliness, hopelessness, sadness, worthlessn...
# 3                              [loneliness, sadness]
# 4                          [emptiness, hopelessness]

# %%
train.to_csv('train.csv')

# %% [markdown]
# # Data Preprocessing

# %%
train['emotions'][0]
# Out:
# ['anger', 'hopelessness', 'sadness']

# %%
from sklearn.preprocessing import MultiLabelBinarizer

mltB=MultiLabelBinarizer()

label_matrix=mltB.fit_transform(train['emotions'])

# Create a DataFrame with binary columns
labels_df = pd.DataFrame(label_matrix, columns=mltB.classes_)

final_training_dataset=pd.concat([train['post'],labels_df],axis=1)

# %%
final_training_dataset.head()
# Out:
#                                                 post  anger  \
# 0  My mum had a boyfriend when I was around 6 or ...      1
# 1  Like, I have a ton of friends, I talk to them ...      1
# 2  I’m writing this as I sit on the side of the r...      1
# 3  Feeling unloved can have a huge impact on the ...      0
# 4  I'm done. I have a bottle of jack danials and ...      0
#
#    brain dysfunction (forget)  emptiness  hopelessness  loneliness  sadness  \
# 0                           0          0             1           0        1
# 1                           0          1             1           1        1
# 2                           0          1             1           1        1
# 3                           0          0             0           1        1
# 4                           0          1             1           0        0
#
#    suicide intent  worthlessness
# 0               0              0
# 1               0              0
# 2               0              1
# ...

# %%
pip install -U sentence-transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.7/345.7 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 93.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 41.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 36.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 902.8 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 52.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from sentence_transformers import SentenceTransformer

# Load a recent and strong model (you can try others too)
model = SentenceTransformer('all-MiniLM-L6-v2')

# %%
# Assume you have a DataFrame called df_final with a 'text' column
train_embeddings = model.encode(final_training_dataset['post'].tolist(), show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/133 [00:00<?, ?it/s]

# %%
import numpy as np

# Save embeddings to disk
np.save('text_embeddings.npy', text_embeddings)

# %%
final_training_dataset.to_csv('final_training_dataset.csv')

# %%
df_test.head()
# Out:
#         id                                             title  \
# 0   w83pst  I worry the best i can ever do is cope, not heal
# 1   f2234m                         I don’t know what to do:(
# 2  17d3zn2                   I want to improve my self worth
# 3   fn48mt                                      I don't know
# 4  11w2im7            Any coping suggestions for loneliness?
#
#                                                 post  \
# 0  On a good day, I can cope with my feelings and...
# 1  He tells me it’s only my fault and I don’t kno...
# 2  I just wish that I could look at myself and se...
# 3  I don't know what to do. I don't know how to s...
# 4  Please don't tell "Go meet people" BS. \n\nI a...
#
#                                                 text  upvotes  \
# 0  I worry the best i can ever do is cope, not he...      105
# 1  I don’t know what to do:( ### He tells me it’s...        1
# 2  I want to improve my self worth ### I just wis...        1
# ...

# %%
df_test['post'][0]
# Out:
# "On a good day, I can cope with my feelings and the trauma I've experienced. I can try to live a normal life.  I've tried many different treatments over the past 5 years, and sometimes I feel like my health has even gotten worse. I have horrible episodes. I definitely don't feel like I've improved at all. I've found methods to cope on most days, not the really bad ones, but most. I've not healed at all,  I think. I feel like the trauma will always be painful and require constant energy, management, coping... I'm tired and I wish it would get easier."

# %%
df_test['emotions'][0]
# Out:
# ['hopelessness', 'sadness']

# %%
from sklearn.preprocessing import MultiLabelBinarizer

mltB=MultiLabelBinarizer()

label_matrix=mltB.fit_transform(df_test['emotions'])

# Create a DataFrame with binary columns
labels_df = pd.DataFrame(label_matrix, columns=mltB.classes_)

final_testing_dataset=pd.concat([df_test['post'],labels_df],axis=1)

# %%
final_testing_dataset.head()
# Out:
#                                                 post  anger  \
# 0  On a good day, I can cope with my feelings and...      0
# 1  He tells me it’s only my fault and I don’t kno...      0
# 2  I just wish that I could look at myself and se...      1
# 3  I don't know what to do. I don't know how to s...      0
# 4  Please don't tell "Go meet people" BS. \n\nI a...      0
#
#    brain dysfunction (forget)  emptiness  hopelessness  loneliness  sadness  \
# 0                           0          0             1           0        1
# 1                           0          0             1           0        1
# 2                           0          1             1           1        1
# 3                           0          0             1           1        1
# 4                           0          0             0           1        0
#
#    suicide intent  worthlessness
# 0               0              0
# 1               0              0
# 2               0              1
# ...

# %%
# Assume you have a DataFrame called df_final with a 'text' column
text_embeddings = model.encode(final_testing_dataset['post'].tolist(), show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/29 [00:00<?, ?it/s]

# %%
text_embeddings.shape
# Out:
# (906, 384)

# %%
import numpy as np

# Save embeddings to disk
np.save('test_embeddings.npy', text_embeddings)

# %%
final_training_dataset.to_csv('final_testing_dataset.csv')

# %%
df_validation.head()
# Out:
#         id                                              title  \
# 0  100krou  If I dissapeared today nobody would care, I’m ...
# 1  17btbhe   i'm afraid of being that suicidal family member.
# 2  102lpvz                       Feeling Isolated From People
# 3   dqjp34                     It just costs too much to live
# 4   f3x166  First Valentine’s Day without a significant other
#
#                                                 post  \
# 0  I feel unloved, I feel like a burden to everyo...
# 1  my grandfather had mental health problem, two ...
# 2  The older I get the more and more I feel isola...
# 3  I can’t handle poverty any more. Everything is...
# 4  This my first Valentine’s Day post separation ...
#
#                                                 text  upvotes  \
# 0  If I dissapeared today nobody would care, I’m ...     19.0
# 1  i'm afraid of being that suicidal family membe...      5.0
# 2  Feeling Isolated From People ### The older I g...     37.0
# ...

# %%
from sklearn.preprocessing import MultiLabelBinarizer

mltB=MultiLabelBinarizer()

label_matrix=mltB.fit_transform(df_validation['emotions'])

# Create a DataFrame with binary columns
labels_df = pd.DataFrame(label_matrix, columns=mltB.classes_)

final_validating_dataset=pd.concat([df_validation['post'],labels_df],axis=1)

# %%
final_validating_dataset.head()
# Out:
#                                                 post  anger  \
# 0  I feel unloved, I feel like a burden to everyo...      0
# 1  my grandfather had mental health problem, two ...      0
# 2  The older I get the more and more I feel isola...      0
# 3  I can’t handle poverty any more. Everything is...      1
# 4  This my first Valentine’s Day post separation ...      0
#
#    brain dysfunction (forget)  emptiness  hopelessness  loneliness  sadness  \
# 0                           0          1             1           1        1
# 1                           0          0             1           0        1
# 2                           0          1             1           1        1
# 3                           0          1             1           0        1
# 4                           0          1             0           1        0
#
#    suicide intent  worthlessness
# 0               1              1
# 1               1              0
# 2               0              1
# ...

# %%
# Assume you have a DataFrame called df_final with a 'text' column
val_embeddings = model.encode(final_validating_dataset['post'].tolist(), show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/29 [00:00<?, ?it/s]

# %%
import numpy as np

# Save embeddings to disk
np.save('val_embeddings.npy', val_embeddings)

# %%
val_embeddings.shape
# Out:
# (906, 384)

# %%
final_validating_dataset.to_csv('final_validating_dataset.csv')

# %%
final_validating_dataset.shape
# Out:
# (906, 9)

# %%
final_testing_dataset.shape
# Out:
# (906, 9)

# %%
final_training_dataset.shape
# Out:
# (4225, 9)

# %% [markdown]
# # Model building

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.multioutput import MultiOutputClassifier

# %%
x=embeddings_train
y=training.drop(columns=['post'])

# %%
model = MultiOutputClassifier(RandomForestClassifier())
model.fit(x, y)

# %%
pred=model.predict(test_embeddings)

# %%
pred.shape
# Out:
# (906, 8)

# %%
test=final_testing_dataset.drop(columns='post')

# %%
test.shape
# Out:
# (906, 8)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.57      0.61       345
#            1       1.00      0.02      0.05       171
#            2       0.73      0.42      0.53       341
#            3       0.76      0.94      0.84       634
#            4       0.85      0.59      0.70       420
#            5       0.78      0.99      0.87       697
#            6       0.87      0.39      0.54       232
#            7       0.70      0.62      0.65       434
#
#    micro avg       0.76      0.68      0.72      3274
#    macro avg       0.80      0.57      0.60      3274
# weighted avg       0.78      0.68      0.69      3274
#  samples avg       0.73      0.70      0.67      3274
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# # Embedding 1st approach

# %%
from sentence_transformers import SentenceTransformer

# Load a recent and strong model (you can try others too)
sen_T = SentenceTransformer('all-MiniLM-L6-v2')

# %%
# Assume you have a DataFrame called df_final with a 'text' column
test_embeddings = sen_T.encode(df_test['text'].tolist(), show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/29 [00:00<?, ?it/s]

# %%
# Assume you have a DataFrame called df_final with a 'text' column
train_embeddings = sen_T.encode(df_train['text'].tolist(), show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/133 [00:00<?, ?it/s]

# %%
import numpy as np

# Save embeddings to disk
np.save('final_test_embeddings.npy', test_embeddings)

# %%
import numpy as np

# Save embeddings to disk
np.save('final_training_embeddings.npy', train_embeddings)

# %%
import numpy as np

# Save embeddings to disk
np.save('final_validation_embeddings.npy', val_embeddings)

# %%
# Assume you have a DataFrame called df_final with a 'text' column
val_embeddings = sen_T.encode(df_validation['text'].tolist(), show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/29 [00:00<?, ?it/s]

# %%
# !pip install tensorflow tensorflow-hub
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.7/319.7 kB 9.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.2
#     Uninstalling protobuf-3.20.2:
#       Successfully uninstalled protobuf-3.20.2
# ...

# %% [markdown]
# # Embedding 2nd approach

# %%
import tensorflow_hub as hub

# Load model
use_model = hub.load("https://tfhub.dev/google/universal-sentence-encoder/4")

# %%
sentences = ["I feel sad and empty inside", "Life is beautiful"]

# Generate 512-dimensional embeddings
embeddings = use_model(sentences)

# Convert to NumPy
import numpy as np
embeddings_np = np.array(embeddings)

print("Shape:", embeddings_np.shape)
# Out:
# Shape: (2, 512)

# %%
import pandas as pd
training=pd.read_csv('/content/final_training_dataset.csv')

# %%
sentences = ["I feel sad and empty inside", "Life is beautiful"]

# Generate 512-dimensional embeddings
embeddings = use_model(training['post'])

# Convert to NumPy
import numpy as np
embeddings_train = np.array(embeddings)

print("Shape:", embeddings_np.shape)
# Out:
# Shape: (4225, 512)

# %%
# Save embeddings to disk
np.save('final_training_embeddings2.npy', embeddings_np)

# %%
import pandas as pd
testing=pd.read_csv('/content/final_testing_dataset.csv')

# %%
sentences = ["I feel sad and empty inside", "Life is beautiful"]

# Generate 512-dimensional embeddings
embeddings = use_model(testing['post'])

# Convert to NumPy
import numpy as np
embeddings_test = np.array(embeddings)

print("Shape:", embeddings_np.shape)
# Out:
# Shape: (4225, 512)

# %%
# Save embeddings to disk
np.save('final_testing_embeddings2.npy', embeddings_np)

# %%
import pandas as pd
validating=pd.read_csv('/content/final_validating_dataset.csv')

# %%
sentences = ["I feel sad and empty inside", "Life is beautiful"]

# Generate 512-dimensional embeddings
embeddings = use_model(validating['post'])

# Convert to NumPy
import numpy as np
embeddings_val = np.array(embeddings)

print("Shape:", embeddings_val.shape)
# Out:
# Shape: (906, 512)

# %%
# Save embeddings to disk
np.save('final_validation_embeddings2.npy', embeddings_val)

# %%
embd=np.load('/content/final_training_embeddings.npy')

# %%
embd.shape
# Out:
# (4225, 384)
