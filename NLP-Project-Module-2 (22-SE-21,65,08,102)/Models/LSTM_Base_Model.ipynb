# %%
# 📌 STEP 1: Imports
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam

# 📌 STEP 2: Load Data
# Make sure you upload these files to Colab or mount from Drive
train_embeddings = np.load('final_training_embeddings2.npy')  # shape: (samples, timesteps, features) /content/final_training_embeddings2.npy
test_embeddings = np.load('final_testing_embeddings2.npy')    # shape: (samples, timesteps, features) /content/final_testing_embeddings2.npy

train_embeddings = np.expand_dims(train_embeddings, axis=1)  # Now (samples, 1, features)
test_embeddings = np.expand_dims(test_embeddings, axis=1)

# Load CSV with labels
train_labels_df = pd.read_csv('final_testing_dataset.csv') #/content/final_testing_dataset.csv

# 📌 STEP 3: Extract multi-label targets
emotion_labels = [
    'anger', 'brain dysfunction (forget)', 'emptiness', 'hopelessness',
    'loneliness', 'sadness', 'suicide intent', 'worthlessness'
]
y_train = train_labels_df[emotion_labels].values  # shape: (samples, 8)

# 📌 STEP 4: Build the LSTM Model
model = Sequential([
    LSTM(64, input_shape=(train_embeddings.shape[1], train_embeddings.shape[2])),
    Dense(32, activation='relu'),
    Dense(8, activation='sigmoid')  # one sigmoid output per emotion
])

# 📌 STEP 5: Compile
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='binary_crossentropy',
              metrics=['accuracy'])

# 📌 STEP 6: Train
model.fit(train_embeddings, y_train, epochs=60, batch_size=32)

# 📌 STEP 7: Predict on test set
predictions = model.predict(test_embeddings)  # shape: (test_samples, 8)

# Convert to binary 0/1 labels
predicted_labels = (predictions > 0.5).astype(int)

# 📌 STEP 8: Show sample predictions
print("Predictions for first 5 test samples:")
for i in range(5):
    print(f"Sample {i+1}: {predicted_labels[i]}")
# Out:
# Epoch 1/60
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.0939 - loss: 0.6462
# Epoch 2/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1327 - loss: 0.5168
# Epoch 3/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.2031 - loss: 0.4741
# Epoch 4/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.2478 - loss: 0.4452
# Epoch 5/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.2770 - loss: 0.4447
# Epoch 6/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.2831 - loss: 0.4323
# Epoch 7/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.2660 - loss: 0.4318
# Epoch 8/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.2838 - loss: 0.4318
# Epoch 9/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.2901 - loss: 0.4265
# Epoch 10/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.2758 - loss: 0.4227
# Epoch 11/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.2809 - loss: 0.4139
# Epoch 12/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.2853 - loss: 0.4164
# Epoch 13/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.2793 - loss: 0.4097
# Epoch 14/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.2890 - loss: 0.4042
# Epoch 15/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.2881 - loss: 0.4061
# Epoch 16/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.2951 - loss: 0.4063
# Epoch 17/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.2855 - loss: 0.4033
# Epoch 18/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.2902 - loss: 0.3994
# Epoch 19/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.2991 - loss: 0.3972
# Epoch 20/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.3149 - loss: 0.3905
# Epoch 21/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.2997 - loss: 0.3936
# Epoch 22/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.2948 - loss: 0.3933
# Epoch 23/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3138 - loss: 0.3879
# Epoch 24/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.2877 - loss: 0.3813
# Epoch 25/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3031 - loss: 0.3822
# Epoch 26/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3036 - loss: 0.3828
# Epoch 27/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3184 - loss: 0.3784
# Epoch 28/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3035 - loss: 0.3799
# Epoch 29/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.2841 - loss: 0.3734
# Epoch 30/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3151 - loss: 0.3752
# Epoch 31/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3121 - loss: 0.3695
# Epoch 32/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.2943 - loss: 0.3658
# Epoch 33/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.3273 - loss: 0.3630
# Epoch 34/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.3218 - loss: 0.3570
# Epoch 35/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3171 - loss: 0.3600
# Epoch 36/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3206 - loss: 0.3540
# Epoch 37/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3231 - loss: 0.3516
# Epoch 38/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3022 - loss: 0.3496
# Epoch 39/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3231 - loss: 0.3482
# Epoch 40/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3192 - loss: 0.3504
# Epoch 41/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3255 - loss: 0.3418
# Epoch 42/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3100 - loss: 0.3438
# Epoch 43/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3158 - loss: 0.3347
# Epoch 44/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3095 - loss: 0.3330
# Epoch 45/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.3122 - loss: 0.3232
# Epoch 46/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3215 - loss: 0.3241
# Epoch 47/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3130 - loss: 0.3205
# Epoch 48/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3223 - loss: 0.3219
# Epoch 49/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3131 - loss: 0.3136
# Epoch 50/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3261 - loss: 0.3062
# Epoch 51/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3225 - loss: 0.3099
# Epoch 52/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3179 - loss: 0.3062
# Epoch 53/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3321 - loss: 0.2988
# Epoch 54/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3240 - loss: 0.2953
# Epoch 55/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3122 - loss: 0.2952
# Epoch 56/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3319 - loss: 0.2898
# Epoch 57/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3260 - loss: 0.2851
# Epoch 58/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.3381 - loss: 0.2848
# Epoch 59/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3252 - loss: 0.2775
# Epoch 60/60
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3184 - loss: 0.2771
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Predictions for first 5 test samples:
# Sample 1: [1 0 0 1 0 1 0 0]
# Sample 2: [1 0 1 1 1 1 0 1]
# Sample 3: [1 0 1 1 1 1 1 1]
# Sample 4: [0 0 0 0 1 1 0 0]
# Sample 5: [0 0 0 1 1 1 0 0]

# %%
from sklearn.metrics import classification_report

# 📌 True labels for test set (assuming same CSV used for test labels)
test_labels_df = pd.read_csv('final_testing_dataset.csv')  # load true test labels
y_test = test_labels_df[emotion_labels].values  # shape: (samples, 8)

# 📌 Generate classification report
report = classification_report(y_test, predicted_labels, target_names=emotion_labels)
print(report)
# Out:
#                             precision    recall  f1-score   support
#
#                      anger       0.87      0.81      0.84      1754
# brain dysfunction (forget)       0.79      0.62      0.70       813
#                  emptiness       0.90      0.78      0.84      1573
#               hopelessness       0.92      0.94      0.93      2919
#                 loneliness       0.89      0.90      0.89      1929
#                    sadness       0.91      0.96      0.93      3260
#             suicide intent       0.82      0.84      0.83      1035
#              worthlessness       0.87      0.84      0.85      2095
#
#                  micro avg       0.89      0.87      0.88     15378
#                  macro avg       0.87      0.83      0.85     15378
#               weighted avg       0.89      0.87      0.88     15378
#                samples avg       0.87      0.85      0.84     15378
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
